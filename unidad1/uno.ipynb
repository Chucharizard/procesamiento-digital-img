# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import cv2

print("NumPy:", np._version_)
print("Pandas:", pd._version_)
print("Matplotlib:", matplotlib._version_)
print("OpenCV:", cv2._version_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 7
#       4 import pandas as pd
#       5 import cv2
# ----> 7 print("NumPy:", np._version_)
#       8 print("Pandas:", pd._version_)
#       9 print("Matplotlib:", matplotlib._version_)
#
# File c:\Users\willy\.conda\envs\pdi26t\lib\site-packages\numpy\__init__.py:414, in __getattr__(attr)
#     411     import numpy.char as char
#     412     return char.chararray
# --> 414 raise AttributeError("module {!r} has no attribute "
#     415                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute '_version_'
